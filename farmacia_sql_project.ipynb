# %% [markdown]
# <a href="https://colab.research.google.com/github/Cleverson-Andrade/projeto-farmacia-sql/blob/main/farmacia_sql_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
